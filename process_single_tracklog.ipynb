# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/home/ganesh/geo/tracklog-A1F70AB6-D3F1-4FF3-AF7E-EB0EF3CC21AB.csv', skiprows=2)
df
# Out:
#          Timestamp   Latitude   Longitude    Altitude  Course  Speed  Bank  \
# 0     1.745184e+09  37.690468 -121.812096  794.947517    -1.0    0.0   NaN
# 1     1.745184e+09  37.690460 -121.812111  787.726375    -1.0    0.0   NaN
# 2     1.745184e+09  37.690449 -121.812119  781.824157    -1.0    0.0   NaN
# 3     1.745184e+09  37.690437 -121.812134  775.918635    -1.0    0.0   NaN
# 4     1.745184e+09  37.690426 -121.812149  770.997375    -1.0    0.0   NaN
# ...            ...        ...         ...         ...     ...    ...   ...
# 6732  1.745192e+09  37.689649 -121.812020  405.072597    -1.0    0.0   NaN
# 6733  1.745192e+09  37.689643 -121.812012  404.923752    -1.0    0.0   NaN
# 6734  1.745192e+09  37.689642 -121.812037  404.542942    -1.0    0.0   NaN
# 6735  1.745192e+09  37.689670 -121.812054  404.988791    -1.0    0.0   NaN
# 6736  1.745192e+09  37.689708 -121.812081  402.312713    -1.0    0.0   NaN
#
#       Pitch  Horizontal Error  Vertical Error
# ...

# %%
plt.figure()
plt.plot(df['Speed'])
plt.xlabel('Elapsed Time (s)')
plt.ylabel('Groundspeed (kt)')
plt.title('Groundspeed over Time')
# Out:
# Text(0.5, 1.0, 'Groundspeed over Time')

# %%
fig = plt.figure()
ax = fig.add_subplot()
scatter = ax.scatter(df['Longitude'], df['Latitude'], c=df['Altitude'], cmap='viridis', s=5)
fig.colorbar(scatter, shrink=0.5, aspect=5, label='Altitude')
ax.set_title('Flight Path')
# Out:
# Text(0.5, 1.0, 'Flight Path')
